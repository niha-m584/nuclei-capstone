# %%
import os
import skimage

# %%
img_path = '/nucleus/projects/HDSI-capstone/ecseg_training_data/train_im/'
imgs = os.listdir(img_path)

# %%
imgs
# Out:
# ['9375.tif',
#  '8535.tif',
#  '8947.tif',
#  '4920.tif',
#  '4552.tif',
#  '8154.tif',
#  '4133.tif',
#  '4694.tif',
#  '5773.tif',
#  '3138.tif',
#  '2778.tif',
#  '7026.tif',
#  '7750.tif',
#  '6110.tif',
#  '5005.tif',
#  '8185.tif',
#  '4645.tif',
#  '8622.tif',
#  '6571.tif',
#  '7496.tif',
#  '7331.tif',
#  '4583.tif',
#  '4224.tif',
#  '8243.tif',
#  '5816.tif',
#  '5464.tif',
#  '7608.tif',
#  '3716.tif',
#  '6048.tif',
#  '6429.tif',
#  '2537.tif',
#  '2945.tif',
#  '7269.tif',
#  '3873.tif',
#  '3060.tif',
#  '7849.tif',
#  '2365.tif',
#  '3957.tif',
#  '3525.tif',
#  '9309.tif',
#  '4289.tif',
#  '8549.tif',
#  '3144.tif',
#  '8128.tif',
#  '4639.tif',
#  '3195.tif',
#  '4258.tif',
#  '5418.tif',
#  '3253.tif',
#  '3986.tif',
#  '2413.tif',
#  '7898.tif',
#  '7674.tif',
#  '6034.tif',
#  '6793.tif',
#  '9146.tif',
#  '5686.tif',
#  '4761.tif',
#  '8706.tif',
#  '6455.tif',
#  '7215.tif',
#  '9527.tif',
#  '5540.tif',
#  '5932.tif',
#  '5591.tif',
#  '9251.tif',
# ...

# %%
skimage.io.imshow(img_path + imgs[0])

# %%
ccs = skimage.measure.label(skimage.io.imread(img_path + imgs[0]))

# %%
skimage.io.imshow(ccs)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
crops = skimage.measure.regionprops(ccs)

# %%
skimage.io.imshow(ccs[crops[0].slice])
